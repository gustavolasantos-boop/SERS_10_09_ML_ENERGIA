# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavolasantos-boop/SERS_10_09_ML_ENERGIA/blob/main/SERS_10_09_ML_ENERGIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercicio
#
# Treinar um modelo preditivo de classificação da estabilidade de uma rede elétrica.
#
# Fonte:

# %% [markdown]
# ##Preparação do ambinte

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learnng
# Algoritmos do sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Separação os dados de treino e teste
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test

# Métrica para classificação
from sklearn.metrics import accuracy_score # acurácia
from sklearn.metrics import confusion_matrix # identificação de onde o modelo errou
from sklearn.metrics import classification_report # resumo de métricas

# %% [markdown]
# Carregar os dados e gerar um DATAFRAME

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/gustavolasantos-boop/SERS_10_09_ML_ENERGIA/main/Data_for_UCI_named.csv')

# %%
dados.head()
# Out:
#        tau1      tau2      tau3  ...        g4      stab     stabf
# 0  2.959060  3.079885  8.381025  ...  0.958034  0.055347  unstable
# 1  9.304097  4.902524  3.047541  ...  0.781760 -0.005957    stable
# 2  8.971707  8.848428  3.046479  ...  0.109853  0.003471  unstable
# 3  0.716415  7.669600  4.486641  ...  0.362718  0.028871  unstable
# 4  3.134112  7.608772  4.943759  ...  0.820923  0.049860  unstable
#
# [5 rows x 14 columns]

# %% [markdown]
# ##Análise Exploratória

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
# Somente estatísticas de atributos categóricos
dados.describe(include = 'object')
# Out:
#            stabf
# count      10000
# unique         2
# top     unstable
# freq        6380

# %%
# somente estatísticas de atributos númericos
dados.describe()
# Out:
#                tau1          tau2  ...            g4          stab
# count  10000.000000  10000.000000  ...  10000.000000  10000.000000
# mean       5.250000      5.250001  ...      0.525000      0.015731
# std        2.742548      2.742549  ...      0.274255      0.036919
# min        0.500793      0.500141  ...      0.050028     -0.080760
# 25%        2.874892      2.875140  ...      0.287494     -0.015557
# 50%        5.250004      5.249981  ...      0.525002      0.017142
# 75%        7.624690      7.624893  ...      0.762433      0.044878
# max        9.999469      9.999837  ...      0.999930      0.109403
#
# [8 rows x 13 columns]

# %%
# Checando a quantidade de classes da coluna alvo (stabf)
dados['stabf'].unique()
# Out:
# array(['unstable', 'stable'], dtype=object)

# %%
# Checando a quantidade de valores de cada classe da coluna alvo (stabf)
dados['stabf'].value_counts()
# Out:
# stabf
# unstable    6380
# stable      3620
# Name: count, dtype: int64

# %% [markdown]
# ## Separação de dados:
#  Entrada (features) -----> X
#
#  Saída(target) -----> y

# %%
#Features
X = dados.drop(['stab','stabf'], axis = 1)
X.head()
# Out:
#        tau1      tau2      tau3  ...        g2        g3        g4
# 0  2.959060  3.079885  8.381025  ...  0.859578  0.887445  0.958034
# 1  9.304097  4.902524  3.047541  ...  0.862414  0.562139  0.781760
# 2  8.971707  8.848428  3.046479  ...  0.766689  0.839444  0.109853
# 3  0.716415  7.669600  4.486641  ...  0.976744  0.929381  0.362718
# 4  3.134112  7.608772  4.943759  ...  0.455450  0.656947  0.820923
#
# [5 rows x 12 columns]

# %%
# Variável alvo(target)
y = dados['stabf']
y.head()
# Out:
# 0    unstable
# 1      stable
# 2    unstable
# 3    unstable
# 4    unstable
# Name: stabf, dtype: object

# %%
# Renomeando as classes da coluna alvo stabf(y)
y = y.map({'unstable': 'instável', 'stable': 'estável'})
y.head()
# Out:
# 0    instável
# 1     estável
# 2    instável
# 3    instável
# 4    instável
# Name: stabf, dtype: object

# %% [markdown]
# ## Separação de dados de treino e teste

# %%
# X_train, X_teste, y_train, y_test
# Amostra aleatório para treino e teste
X_train, X_teste, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 17)
# Amostra estratificada(balanceamento de classes)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 17, stratify = y)

# %%
X.shape
# Out:
# (10000, 12)

# %%
X_train.shape # 80% dos dados para treino
# Out:
# (8000, 12)

# %%
X_teste.shape # 20% dos dados para teste
# Out:
# (2000, 12)

# %% [markdown]
# ##Treinamento e geração das previsões do modelo

# %%
# Instanciando o modelo
modelo_LR = LogisticRegression()
# Treinando o modelo
modelo_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Gerando as previsões
y_predict = modelo_LR.predict(X_teste)
y_predict
# Out:
# array(['instável', 'instável', 'estável', ..., 'instável', 'instável',
#        'instável'], dtype=object)

# %% [markdown]
# ## Avaliação do modelo

# %%
# Acurácia
acuracia = 100 * accuracy_score(y_test, y_predict)
print(f'A acurácia do modelo baseado em Regressão Logística é: {acuracia:.2f}%')
# Out:
# A acurácia do modelo baseado em Regressão Logística é: 80.40

# %%
# Matriz de confusão usando o seaborn e matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_confusao, annot=True, fmt='g', cmap='Blues',
            xticklabels=['instável', 'estável'], yticklabels=['instável', 'estável'])
plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão')
plt.show()

# %%
# classfication Report usando seaborn e matplolib
report = classification_report(y_test, y_predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      estável       0.74      0.69      0.72       712
#     instável       0.84      0.86      0.85      1288
#
#     accuracy                           0.80      2000
#    macro avg       0.79      0.78      0.78      2000
# weighted avg       0.80      0.80      0.80      2000
